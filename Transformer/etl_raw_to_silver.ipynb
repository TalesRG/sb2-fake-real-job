# %%
import urllib.request
import os

jdbc_jar_path = "/tmp/postgresql-42.7.3.jar"

if not os.path.exists(jdbc_jar_path):
    urllib.request.urlretrieve(
        "https://jdbc.postgresql.org/download/postgresql-42.7.3.jar",
        jdbc_jar_path
    )

jdbc_jar_path
# Out:
# '/tmp/postgresql-42.7.3.jar'

# %%
import os
import subprocess
from pyspark.sql import SparkSession

# Configura JAVA_HOME (como antes)
java_home = subprocess.check_output(
    ["/usr/libexec/java_home", "-v", "11"]
).decode("utf-8").strip()

os.environ["JAVA_HOME"] = java_home
os.environ["PATH"] = java_home + "/bin:" + os.environ["PATH"]

# Cria Spark com o driver JDBC
spark = SparkSession.builder \
    .appName("raw-to-silver-etl") \
    .config("spark.jars", jdbc_jar_path) \
    .getOrCreate()

spark.sparkContext.setLogLevel("ERROR")

spark
# Out:
# 26/01/19 02:50:58 WARN Utils: Your hostname, MacBook-Air-de-Tales.local resolves to a loopback address: 127.0.0.1; using 192.168.1.18 instead (on interface en0)
# 26/01/19 02:50:58 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.unsafe.Platform (file:/Users/tales/PycharmProjects/sb2-fake-real-job/.venv/lib/python3.10/site-packages/pyspark/jars/spark-unsafe_2.12-3.0.3.jar) to constructor java.nio.DirectByteBuffer(long,int)
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.unsafe.Platform
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# 26/01/19 02:50:58 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/01/19 02:50:58 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.1.18:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.0.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>raw-to-silver-etl</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder \
    .appName("raw-to-silver-etl") \
    .getOrCreate()

# %%
spark.sparkContext.setLogLevel("ERROR")

# %%
raw_path = "../Data Layer/raw/data_raw.csv"

# %%
df_raw = spark.read \
    .option("header", True) \
    .option("inferSchema", False) \
    .csv(raw_path)

# %%
df_raw.show(5)
# Out:
# +------+--------------------+--------------------+--------------------+--------------------+------------+--------------------+----------+---------------+---------------+-------------+-------------------------+---------------+----------+------------+--------------------+-----------------+--------------------+--------+------------------+------------+-------------+----------------+-----------+-------+
# |job_id|           job_title|     job_description|        requirements|            benefits|company_name|     company_profile|  industry|employment_type|       location| salary_range|required_experience_years|education_level|department|posting_date|application_deadline|    contact_email|     company_website|has_logo|num_open_positions|job_function|telecommuting|    fraud_reason|text_length|is_fake|
# +------+--------------------+--------------------+--------------------+--------------------+------------+--------------------+----------+---------------+---------------+-------------+-------------------------+---------------+----------+------------+--------------------+-----------------+--------------------+--------+------------------+------------+-------------+----------------+-----------+-------+
# |     1|   Software Engineer|We are looking fo...|Candidates should...|We offer required...| Company_543|Our company growt...| Marketing|       Contract|Toronto, Canada|    $60k-$80k|                        8|    High School|     Sales|  2023-11-24|          2024-09-16|hr312@company.com|https://www.compa...|       0|                 3|  Management|            0|            null|         89|      0|
# |     2|      Content Writer|We are looking fo...|Candidates should...|We offer fast-pac...| Company_192|Our company fast-...|   Finance|      Full-time|Toronto, Canada|    $40k-$60k|                       10|       Bachelor|        HR|  2023-03-03|          2024-10-18|hr127@company.com|https://www.compa...|       0|                10| Development|            1|            null|         89|      0|
# |     3|Customer Support ...|We are looking fo...|Candidates should...|We offer skills e...|        null|We are global inn...|Healthcare|     Internship|         Remote|    $60k-$80k|                        3|       Bachelor| Marketing|  2023-07-31|          2024-01-13|  job92@gmail.com|                null|       0|                 6|     Support|            0|Suspicious email|         69|      1|
# |     4|        Data Analyst|We are looking fo...|Candidates should...|We offer strategy...|  Company_95|Our company fast-...|Healthcare|      Part-time|Berlin, Germany|Not Disclosed|                       10|       Bachelor|     Sales|  2023-08-14|          2024-02-09|hr366@company.com|https://www.compa...|       1|                 4|  Management|            1|            null|         89|      0|
# |     5|    Graphic Designer|We are looking fo...|Candidates should...|We offer opportun...|        null|We are global exp...|    Retail|      Part-time|     London, UK|    $60k-$80k|                        7|    High School|    Design|  2023-04-22|          2024-08-26| job359@gmail.com|                null|       0|                 5|  Management|            0|  No salary info|         69|      1|
# +------+--------------------+--------------------+--------------------+--------------------+------------+--------------------+----------+---------------+---------------+-------------+-------------------------+---------------+----------+------------+--------------------+-----------------+--------------------+--------+------------------+------------+-------------+----------------+-----------+-------+
# only showing top 5 rows

# %%
df_raw.printSchema()
# Out:
# root
#  |-- job_id: string (nullable = true)
#  |-- job_title: string (nullable = true)
#  |-- job_description: string (nullable = true)
#  |-- requirements: string (nullable = true)
#  |-- benefits: string (nullable = true)
#  |-- company_name: string (nullable = true)
#  |-- company_profile: string (nullable = true)
#  |-- industry: string (nullable = true)
#  |-- employment_type: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- salary_range: string (nullable = true)
#  |-- required_experience_years: string (nullable = true)
#  |-- education_level: string (nullable = true)
#  |-- department: string (nullable = true)
#  |-- posting_date: string (nullable = true)
#  |-- application_deadline: string (nullable = true)
#  |-- contact_email: string (nullable = true)
#  |-- company_website: string (nullable = true)
#  |-- has_logo: string (nullable = true)
#  |-- num_open_positions: string (nullable = true)
#  |-- job_function: string (nullable = true)
#  |-- telecommuting: string (nullable = true)
#  |-- fraud_reason: string (nullable = true)
#  |-- text_length: string (nullable = true)
#  |-- is_fake: string (nullable = true)

# %%
df_raw.count()
# Out:
# 3000

# %%
from pyspark.sql.functions import col

df = df_raw.select(
    col("job_id"),
    col("job_title"),
    col("company_name"),
    col("location"),
    col("employment_type"),
    col("posting_date"),
    col("application_deadline"),
    col("salary_range"),
    col("text_length"),
    col("is_fake")
)

# %%
df_raw.select("is_fake").distinct().show(20, truncate=False)
# Out:
# +-------+
# |is_fake|
# +-------+
# |0      |
# |1      |
# +-------+

# %%
df_raw.groupBy("is_fake").count().show()
# Out:
# +-------+-----+
# |is_fake|count|
# +-------+-----+
# |      0| 1528|
# |      1| 1472|
# +-------+-----+

# %%
from pyspark.sql.functions import col, to_date, when, lower, current_timestamp

df = (
    df.withColumn(
    "is_fake",
    when(col("is_fake") == '1', True).otherwise(False)
)
    .withColumn("job_id", col("job_id").cast("int"))
    .withColumn("posting_date", to_date("posting_date", "yyyy-MM-dd"))
    .withColumn("application_deadline", to_date("application_deadline", "yyyy-MM-dd"))
    .withColumn("text_length", col("text_length").cast("int"))
    .withColumn("etl_processed_at", current_timestamp())

)

# %%
df = df.filter(col("job_id").isNotNull())
df = df.filter(col("job_title").isNotNull())
df = df.filter(col("company_name").isNotNull())

# %%
df = df.dropDuplicates(["job_id"])

# %%
from pyspark.sql.functions import current_timestamp

df = df.withColumn(
    "etl_processed_at",
    current_timestamp()
)

# %%
df.printSchema()
df.show(5)
df.count()
# Out:
# root
#  |-- job_id: integer (nullable = true)
#  |-- job_title: string (nullable = true)
#  |-- company_name: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- employment_type: string (nullable = true)
#  |-- posting_date: date (nullable = true)
#  |-- application_deadline: date (nullable = true)
#  |-- salary_range: string (nullable = true)
#  |-- text_length: integer (nullable = true)
#  |-- is_fake: boolean (nullable = false)
#  |-- etl_processed_at: timestamp (nullable = false)
#
# +------+-----------------+------------+---------------+---------------+------------+--------------------+-------------+-----------+-------+--------------------+
# |job_id|        job_title|company_name|       location|employment_type|posting_date|application_deadline| salary_range|text_length|is_fake|    etl_processed_at|
# +------+-----------------+------------+---------------+---------------+------------+--------------------+-------------+-----------+-------+--------------------+
# |   148|     Data Analyst| Company_650|     London, UK|       Contract|  2023-12-29|          2024-10-05|    $40k-$60k|         89|  false|2026-01-19 02:51:...|
# |   471|Marketing Manager| Company_886|     London, UK|     Internship|  2023-06-08|          2024-09-18|    $60k-$80k|         89|  false|2026-01-19 02:51:...|
# |  1088|     Data Analyst| Company_159|Berlin, Germany|      Temporary|  2023-07-01|          2024-03-11|   $80k-$100k|         89|  false|2026-01-19 02:51:...|
# |  1342|   HR Coordinator|Company_1011|     London, UK|      Full-time|  2023-07-31|          2024-04-22|Not Disclosed|         89|  false|2026-01-19 02:51:...|
# |  1591|   HR Coordinator| Company_585|         Remote|      Temporary|  2023-11-05|          2024-11-28|Not Disclosed|         89|  false|2026-01-19 02:51:...|
# +------+-----------------+------------+---------------+---------------+------------+--------------------+-------------+-----------+-------+--------------------+
# only showing top 5 rows
# 1528

# %%
df_raw.printSchema()
df_raw.columns
# Out:
# root
#  |-- job_id: string (nullable = true)
#  |-- job_title: string (nullable = true)
#  |-- job_description: string (nullable = true)
#  |-- requirements: string (nullable = true)
#  |-- benefits: string (nullable = true)
#  |-- company_name: string (nullable = true)
#  |-- company_profile: string (nullable = true)
#  |-- industry: string (nullable = true)
#  |-- employment_type: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- salary_range: string (nullable = true)
#  |-- required_experience_years: string (nullable = true)
#  |-- education_level: string (nullable = true)
#  |-- department: string (nullable = true)
#  |-- posting_date: string (nullable = true)
#  |-- application_deadline: string (nullable = true)
#  |-- contact_email: string (nullable = true)
#  |-- company_website: string (nullable = true)
#  |-- has_logo: string (nullable = true)
#  |-- num_open_positions: string (nullable = true)
#  |-- job_function: string (nullable = true)
#  |-- telecommuting: string (nullable = true)
#  |-- fraud_reason: string (nullable = true)
#  |-- text_length: string (nullable = true)
#  |-- is_fake: string (nullable = true)
# ['job_id',
#  'job_title',
#  'job_description',
#  'requirements',
#  'benefits',
#  'company_name',
#  'company_profile',
#  'industry',
#  'employment_type',
#  'location',
#  'salary_range',
#  'required_experience_years',
#  'education_level',
#  'department',
#  'posting_date',
#  'application_deadline',
#  'contact_email',
#  'company_website',
#  'has_logo',
#  'num_open_positions',
#  'job_function',
#  'telecommuting',
#  'fraud_reason',
#  'text_length',
#  'is_fake']

# %%
jdbc_url = "jdbc:postgresql://localhost:5432/analytics"

connection_properties = {
    "user": "postgres",
    "password": "senha123",
    "driver": "org.postgresql.Driver"
}

# %%
df_silver = df.select(
    "job_id",
    "job_title",
    "company_name",
    "location",
    "employment_type",
    "posting_date",
    "application_deadline",
    "salary_range",
    "text_length",
    "is_fake",
    "etl_processed_at"
)

# %%
df_silver.write \
    .jdbc(
        url=jdbc_url,
        table="silver_job_postings",
        mode="append",
        properties=connection_properties
    )

# %%
print("RAW:", df_raw.count())
print("SILVER:", df.count())
print("SILVER FINAL:", df_silver.count())
# Out:
# RAW: 3000
# SILVER: 1528
# SILVER FINAL: 1528
